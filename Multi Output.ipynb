# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 959us/sample - loss: 234.8306 - y1_output_loss: 113.6619 - y2_output_loss: 118.9393 - y1_output_root_mean_squared_error: 10.7125 - y2_output_root_mean_squared_error: 10.9578 - val_loss: 28.4144 - val_y1_output_loss: 12.4239 - val_y2_output_loss: 15.5497 - val_y1_output_root_mean_squared_error: 3.5678 - val_y2_output_root_mean_squared_error: 3.9604
# Epoch 2/500
# 614/614 [==============================] - 0s 151us/sample - loss: 31.0825 - y1_output_loss: 12.2009 - y2_output_loss: 18.7343 - y1_output_root_mean_squared_error: 3.5069 - y2_output_root_mean_squared_error: 4.3341 - val_loss: 32.7547 - val_y1_output_loss: 11.9480 - val_y2_output_loss: 19.8600 - val_y1_output_root_mean_squared_error: 3.5126 - val_y2_output_root_mean_squared_error: 4.5185
# Epoch 3/500
# 614/614 [==============================] - 0s 133us/sample - loss: 27.1390 - y1_output_loss: 10.9720 - y2_output_loss: 16.1822 - y1_output_root_mean_squared_error: 3.3091 - y2_output_root_mean_squared_error: 4.0236 - val_loss: 23.9437 - val_y1_output_loss: 9.2120 - val_y2_output_loss: 14.3020 - val_y1_output_root_mean_squared_error: 3.0726 - val_y2_output_root_mean_squared_error: 3.8083
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 27.8757 - y1_output_loss: 10.7708 - y2_output_loss: 17.2974 - y1_output_root_mean_squared_error: 3.2846 - y2_output_root_mean_squared_error: 4.1336 - val_loss: 33.1744 - val_y1_output_loss: 9.1530 - val_y2_output_loss: 23.2631 - val_y1_output_root_mean_squared_error: 3.0574 - val_y2_output_root_mean_squared_error: 4.8813
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 24.9510 - y1_output_loss: 9.5564 - y2_output_loss: 15.3850 - y1_output_root_mean_squared_error: 3.0885 - y2_output_root_mean_squared_error: 3.9259 - val_loss: 23.9513 - val_y1_output_loss: 8.3293 - val_y2_output_loss: 15.6079 - val_y1_output_root_mean_squared_error: 2.9010 - val_y2_output_root_mean_squared_error: 3.9415
# Epoch 6/500
# 614/614 [==============================] - 0s 138us/sample - loss: 22.2498 - y1_output_loss: 9.1390 - y2_output_loss: 12.9623 - y1_output_root_mean_squared_error: 3.0346 - y2_output_root_mean_squared_error: 3.6113 - val_loss: 21.3340 - val_y1_output_loss: 7.5218 - val_y2_output_loss: 13.5069 - val_y1_output_root_mean_squared_error: 2.7636 - val_y2_output_root_mean_squared_error: 3.7009
# Epoch 7/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.1342 - y1_output_loss: 8.4506 - y2_output_loss: 12.5942 - y1_output_root_mean_squared_error: 2.9088 - y2_output_root_mean_squared_error: 3.5599 - val_loss: 18.0206 - val_y1_output_loss: 7.3331 - val_y2_output_loss: 10.3627 - val_y1_output_root_mean_squared_error: 2.7362 - val_y2_output_root_mean_squared_error: 3.2456
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.8144 - y1_output_loss: 8.0416 - y2_output_loss: 11.6033 - y1_output_root_mean_squared_error: 2.8490 - y2_output_root_mean_squared_error: 3.4202 - val_loss: 24.4561 - val_y1_output_loss: 7.9241 - val_y2_output_loss: 16.1851 - val_y1_output_root_mean_squared_error: 2.8308 - val_y2_output_root_mean_squared_error: 4.0550
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.6310 - y1_output_loss: 8.7387 - y2_output_loss: 14.8748 - y1_output_root_mean_squared_error: 2.9607 - y2_output_root_mean_squared_error: 3.8556 - val_loss: 29.7383 - val_y1_output_loss: 9.1213 - val_y2_output_loss: 19.9944 - val_y1_output_root_mean_squared_error: 3.0618 - val_y2_output_root_mean_squared_error: 4.5126
# Epoch 10/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.1980 - y1_output_loss: 8.0538 - y2_output_loss: 14.1635 - y1_output_root_mean_squared_error: 2.8395 - y2_output_root_mean_squared_error: 3.7597 - val_loss: 47.0553 - val_y1_output_loss: 16.5793 - val_y2_output_loss: 29.3079 - val_y1_output_root_mean_squared_error: 4.1289 - val_y2_output_root_mean_squared_error: 5.4779
# Epoch 11/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.2746 - y1_output_loss: 7.4053 - y2_output_loss: 9.8394 - y1_output_root_mean_squared_error: 2.7191 - y2_output_root_mean_squared_error: 3.1434 - val_loss: 23.7711 - val_y1_output_loss: 9.7496 - val_y2_output_loss: 13.5339 - val_y1_output_root_mean_squared_error: 3.1650 - val_y2_output_root_mean_squared_error: 3.7086
# Epoch 12/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.0433 - y1_output_loss: 7.2925 - y2_output_loss: 11.6156 - y1_output_root_mean_squared_error: 2.7120 - y2_output_root_mean_squared_error: 3.4188 - val_loss: 38.7565 - val_y1_output_loss: 12.5189 - val_y2_output_loss: 25.4232 - val_y1_output_root_mean_squared_error: 3.5862 - val_y2_output_root_mean_squared_error: 5.0888
# Epoch 13/500
# 614/614 [==============================] - 0s 133us/sample - loss: 18.5255 - y1_output_loss: 7.0283 - y2_output_loss: 11.4408 - y1_output_root_mean_squared_error: 2.6460 - y2_output_root_mean_squared_error: 3.3948 - val_loss: 16.1985 - val_y1_output_loss: 7.4740 - val_y2_output_loss: 8.4552 - val_y1_output_root_mean_squared_error: 2.7648 - val_y2_output_root_mean_squared_error: 2.9248
# Epoch 14/500
# 614/614 [==============================] - 0s 134us/sample - loss: 18.1736 - y1_output_loss: 7.1121 - y2_output_loss: 10.9640 - y1_output_root_mean_squared_error: 2.6762 - y2_output_root_mean_squared_error: 3.3183 - val_loss: 17.3133 - val_y1_output_loss: 7.3644 - val_y2_output_loss: 9.5499 - val_y1_output_root_mean_squared_error: 2.7416 - val_y2_output_root_mean_squared_error: 3.1300
# Epoch 15/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.2036 - y1_output_loss: 6.3298 - y2_output_loss: 9.7765 - y1_output_root_mean_squared_error: 2.5228 - y2_output_root_mean_squared_error: 3.1367 - val_loss: 20.9576 - val_y1_output_loss: 7.6229 - val_y2_output_loss: 12.9354 - val_y1_output_root_mean_squared_error: 2.7922 - val_y2_output_root_mean_squared_error: 3.6279
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.8605 - y1_output_loss: 6.1771 - y2_output_loss: 9.9640 - y1_output_root_mean_squared_error: 2.4863 - y2_output_root_mean_squared_error: 3.1111 - val_loss: 51.4445 - val_y1_output_loss: 12.1077 - val_y2_output_loss: 38.4746 - val_y1_output_root_mean_squared_error: 3.5188 - val_y2_output_root_mean_squared_error: 6.2500
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.7697 - y1_output_loss: 5.9412 - y2_output_loss: 9.9073 - y1_output_root_mean_squared_error: 2.4251 - y2_output_root_mean_squared_error: 3.1446 - val_loss: 34.8359 - val_y1_output_loss: 11.8212 - val_y2_output_loss: 22.7154 - val_y1_output_root_mean_squared_error: 3.4309 - val_y2_output_root_mean_squared_error: 4.8026
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.3861 - y1_output_loss: 5.5853 - y2_output_loss: 9.7304 - y1_output_root_mean_squared_error: 2.3725 - y2_output_root_mean_squared_error: 3.1237 - val_loss: 20.8723 - val_y1_output_loss: 7.1374 - val_y2_output_loss: 13.3450 - val_y1_output_root_mean_squared_error: 2.7019 - val_y2_output_root_mean_squared_error: 3.6840
# Epoch 19/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.8479 - y1_output_loss: 6.6504 - y2_output_loss: 12.1756 - y1_output_root_mean_squared_error: 2.5725 - y2_output_root_mean_squared_error: 3.4972 - val_loss: 26.0292 - val_y1_output_loss: 8.1663 - val_y2_output_loss: 17.5784 - val_y1_output_root_mean_squared_error: 2.8537 - val_y2_output_root_mean_squared_error: 4.2292
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.6437 - y1_output_loss: 4.9514 - y2_output_loss: 7.5768 - y1_output_root_mean_squared_error: 2.2348 - y2_output_root_mean_squared_error: 2.7657 - val_loss: 14.7125 - val_y1_output_loss: 6.6053 - val_y2_output_loss: 7.7607 - val_y1_output_root_mean_squared_error: 2.5947 - val_y2_output_root_mean_squared_error: 2.8249
# Epoch 21/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.3180 - y1_output_loss: 5.3144 - y2_output_loss: 9.0547 - y1_output_root_mean_squared_error: 2.3041 - y2_output_root_mean_squared_error: 3.0016 - val_loss: 20.3177 - val_y1_output_loss: 7.9598 - val_y2_output_loss: 11.9935 - val_y1_output_root_mean_squared_error: 2.8281 - val_y2_output_root_mean_squared_error: 3.5099
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.6015 - y1_output_loss: 5.4778 - y2_output_loss: 9.3014 - y1_output_root_mean_squared_error: 2.3100 - y2_output_root_mean_squared_error: 3.0439 - val_loss: 33.1193 - val_y1_output_loss: 9.3732 - val_y2_output_loss: 23.4203 - val_y1_output_root_mean_squared_error: 3.0501 - val_y2_output_root_mean_squared_error: 4.8802
# Epoch 23/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.2624 - y1_output_loss: 5.3004 - y2_output_loss: 8.8895 - y1_output_root_mean_squared_error: 2.3092 - y2_output_root_mean_squared_error: 2.9883 - val_loss: 14.7008 - val_y1_output_loss: 5.7611 - val_y2_output_loss: 8.5888 - val_y1_output_root_mean_squared_error: 2.4232 - val_y2_output_root_mean_squared_error: 2.9713
# Epoch 24/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.4337 - y1_output_loss: 4.1800 - y2_output_loss: 7.2030 - y1_output_root_mean_squared_error: 2.0509 - y2_output_root_mean_squared_error: 2.6884 - val_loss: 17.3762 - val_y1_output_loss: 7.4110 - val_y2_output_loss: 9.4724 - val_y1_output_root_mean_squared_error: 2.7596 - val_y2_output_root_mean_squared_error: 3.1242
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.0779 - y1_output_loss: 4.3360 - y2_output_loss: 7.9716 - y1_output_root_mean_squared_error: 2.0713 - y2_output_root_mean_squared_error: 2.7906 - val_loss: 23.3239 - val_y1_output_loss: 7.7021 - val_y2_output_loss: 14.9261 - val_y1_output_root_mean_squared_error: 2.8162 - val_y2_output_root_mean_squared_error: 3.9234
# Epoch 26/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.1422 - y1_output_loss: 4.7409 - y2_output_loss: 8.3531 - y1_output_root_mean_squared_error: 2.1830 - y2_output_root_mean_squared_error: 2.8942 - val_loss: 13.2993 - val_y1_output_loss: 5.9417 - val_y2_output_loss: 7.1464 - val_y1_output_root_mean_squared_error: 2.4554 - val_y2_output_root_mean_squared_error: 2.6964
# Epoch 27/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.7942 - y1_output_loss: 3.9545 - y2_output_loss: 6.7890 - y1_output_root_mean_squared_error: 1.9936 - y2_output_root_mean_squared_error: 2.6114 - val_loss: 11.7405 - val_y1_output_loss: 5.0796 - val_y2_output_loss: 6.3570 - val_y1_output_root_mean_squared_error: 2.2799 - val_y2_output_root_mean_squared_error: 2.5578
# Epoch 28/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.7746 - y1_output_loss: 3.5952 - y2_output_loss: 6.1059 - y1_output_root_mean_squared_error: 1.9022 - y2_output_root_mean_squared_error: 2.4812 - val_loss: 11.0843 - val_y1_output_loss: 4.6077 - val_y2_output_loss: 6.1885 - val_y1_output_root_mean_squared_error: 2.1709 - val_y2_output_root_mean_squared_error: 2.5242
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.0273 - y1_output_loss: 3.9950 - y2_output_loss: 7.2240 - y1_output_root_mean_squared_error: 1.9894 - y2_output_root_mean_squared_error: 2.6588 - val_loss: 20.5168 - val_y1_output_loss: 6.3869 - val_y2_output_loss: 13.5007 - val_y1_output_root_mean_squared_error: 2.5558 - val_y2_output_root_mean_squared_error: 3.7396
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.1457 - y1_output_loss: 4.2928 - y2_output_loss: 8.7910 - y1_output_root_mean_squared_error: 2.0799 - y2_output_root_mean_squared_error: 2.9698 - val_loss: 11.8542 - val_y1_output_loss: 3.8947 - val_y2_output_loss: 7.6325 - val_y1_output_root_mean_squared_error: 1.9907 - val_y2_output_root_mean_squared_error: 2.8092
# Epoch 31/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.8331 - y1_output_loss: 3.6024 - y2_output_loss: 6.2271 - y1_output_root_mean_squared_error: 1.8962 - y2_output_root_mean_squared_error: 2.4975 - val_loss: 10.5343 - val_y1_output_loss: 4.2274 - val_y2_output_loss: 6.0577 - val_y1_output_root_mean_squared_error: 2.0667 - val_y2_output_root_mean_squared_error: 2.5026
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.1072 - y1_output_loss: 3.5991 - y2_output_loss: 6.4364 - y1_output_root_mean_squared_error: 1.9029 - y2_output_root_mean_squared_error: 2.5468 - val_loss: 10.5138 - val_y1_output_loss: 4.1152 - val_y2_output_loss: 6.1056 - val_y1_output_root_mean_squared_error: 2.0553 - val_y2_output_root_mean_squared_error: 2.5079
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.8034 - y1_output_loss: 3.4842 - y2_output_loss: 6.2547 - y1_output_root_mean_squared_error: 1.8696 - y2_output_root_mean_squared_error: 2.5116 - val_loss: 9.4401 - val_y1_output_loss: 3.7928 - val_y2_output_loss: 5.4297 - val_y1_output_root_mean_squared_error: 1.9615 - val_y2_output_root_mean_squared_error: 2.3649
# Epoch 34/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.7349 - y1_output_loss: 3.0783 - y2_output_loss: 5.8425 - y1_output_root_mean_squared_error: 1.7479 - y2_output_root_mean_squared_error: 2.3832 - val_loss: 9.9947 - val_y1_output_loss: 3.8143 - val_y2_output_loss: 5.9709 - val_y1_output_root_mean_squared_error: 1.9537 - val_y2_output_root_mean_squared_error: 2.4855
# Epoch 35/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.3121 - y1_output_loss: 3.0369 - y2_output_loss: 6.3510 - y1_output_root_mean_squared_error: 1.7444 - y2_output_root_mean_squared_error: 2.5038 - val_loss: 22.1255 - val_y1_output_loss: 6.8563 - val_y2_output_loss: 14.6105 - val_y1_output_root_mean_squared_error: 2.6613 - val_y2_output_root_mean_squared_error: 3.8785
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.9791 - y1_output_loss: 3.3810 - y2_output_loss: 6.5393 - y1_output_root_mean_squared_error: 1.8384 - y2_output_root_mean_squared_error: 2.5689 - val_loss: 8.4880 - val_y1_output_loss: 3.4903 - val_y2_output_loss: 4.7591 - val_y1_output_root_mean_squared_error: 1.8839 - val_y2_output_root_mean_squared_error: 2.2224
# Epoch 37/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.2663 - y1_output_loss: 3.1025 - y2_output_loss: 6.1090 - y1_output_root_mean_squared_error: 1.7671 - y2_output_root_mean_squared_error: 2.4786 - val_loss: 10.1485 - val_y1_output_loss: 3.2601 - val_y2_output_loss: 6.6933 - val_y1_output_root_mean_squared_error: 1.8077 - val_y2_output_root_mean_squared_error: 2.6231
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.4305 - y1_output_loss: 3.3268 - y2_output_loss: 6.1549 - y1_output_root_mean_squared_error: 1.8057 - y2_output_root_mean_squared_error: 2.4839 - val_loss: 8.3591 - val_y1_output_loss: 2.7713 - val_y2_output_loss: 5.3732 - val_y1_output_root_mean_squared_error: 1.6782 - val_y2_output_root_mean_squared_error: 2.3543
# Epoch 39/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.5477 - y1_output_loss: 2.6487 - y2_output_loss: 4.9500 - y1_output_root_mean_squared_error: 1.6301 - y2_output_root_mean_squared_error: 2.2114 - val_loss: 27.0180 - val_y1_output_loss: 6.7420 - val_y2_output_loss: 19.5169 - val_y1_output_root_mean_squared_error: 2.6447 - val_y2_output_root_mean_squared_error: 4.4748
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.3289 - y1_output_loss: 2.7896 - y2_output_loss: 5.5209 - y1_output_root_mean_squared_error: 1.6614 - y2_output_root_mean_squared_error: 2.3598 - val_loss: 8.5460 - val_y1_output_loss: 3.6174 - val_y2_output_loss: 4.7438 - val_y1_output_root_mean_squared_error: 1.9215 - val_y2_output_root_mean_squared_error: 2.2031
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.6430 - y1_output_loss: 2.4369 - y2_output_loss: 5.1573 - y1_output_root_mean_squared_error: 1.5643 - y2_output_root_mean_squared_error: 2.2795 - val_loss: 7.6940 - val_y1_output_loss: 2.8545 - val_y2_output_loss: 4.6531 - val_y1_output_root_mean_squared_error: 1.6939 - val_y2_output_root_mean_squared_error: 2.1965
# Epoch 42/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0309 - y1_output_loss: 2.4158 - y2_output_loss: 4.5540 - y1_output_root_mean_squared_error: 1.5617 - y2_output_root_mean_squared_error: 2.1429 - val_loss: 7.2259 - val_y1_output_loss: 2.6057 - val_y2_output_loss: 4.4797 - val_y1_output_root_mean_squared_error: 1.6139 - val_y2_output_root_mean_squared_error: 2.1497
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.2569 - y1_output_loss: 3.6623 - y2_output_loss: 7.4907 - y1_output_root_mean_squared_error: 1.9228 - y2_output_root_mean_squared_error: 2.7495 - val_loss: 7.1428 - val_y1_output_loss: 2.4785 - val_y2_output_loss: 4.4430 - val_y1_output_root_mean_squared_error: 1.5930 - val_y2_output_root_mean_squared_error: 2.1460
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.6138 - y1_output_loss: 2.6217 - y2_output_loss: 5.9494 - y1_output_root_mean_squared_error: 1.6260 - y2_output_root_mean_squared_error: 2.4433 - val_loss: 13.7882 - val_y1_output_loss: 4.1147 - val_y2_output_loss: 9.2480 - val_y1_output_root_mean_squared_error: 2.0576 - val_y2_output_root_mean_squared_error: 3.0910
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.1496 - y1_output_loss: 2.3445 - y2_output_loss: 4.7823 - y1_output_root_mean_squared_error: 1.5285 - y2_output_root_mean_squared_error: 2.1939 - val_loss: 7.0582 - val_y1_output_loss: 2.8173 - val_y2_output_loss: 4.1227 - val_y1_output_root_mean_squared_error: 1.6753 - val_y2_output_root_mean_squared_error: 2.0620
# Epoch 46/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.2286 - y1_output_loss: 2.3193 - y2_output_loss: 4.9357 - y1_output_root_mean_squared_error: 1.5233 - y2_output_root_mean_squared_error: 2.2155 - val_loss: 7.2318 - val_y1_output_loss: 2.8002 - val_y2_output_loss: 4.2116 - val_y1_output_root_mean_squared_error: 1.6904 - val_y2_output_root_mean_squared_error: 2.0915
# Epoch 47/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.2990 - y1_output_loss: 2.2443 - y2_output_loss: 5.1161 - y1_output_root_mean_squared_error: 1.4961 - y2_output_root_mean_squared_error: 2.2496 - val_loss: 10.7785 - val_y1_output_loss: 3.9589 - val_y2_output_loss: 6.4735 - val_y1_output_root_mean_squared_error: 2.0216 - val_y2_output_root_mean_squared_error: 2.5868
# Epoch 48/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.3420 - y1_output_loss: 2.2361 - y2_output_loss: 5.0584 - y1_output_root_mean_squared_error: 1.4965 - y2_output_root_mean_squared_error: 2.2588 - val_loss: 7.3023 - val_y1_output_loss: 2.9308 - val_y2_output_loss: 4.1627 - val_y1_output_root_mean_squared_error: 1.7344 - val_y2_output_root_mean_squared_error: 2.0722
# Epoch 49/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.3837 - y1_output_loss: 1.9931 - y2_output_loss: 4.3608 - y1_output_root_mean_squared_error: 1.4162 - y2_output_root_mean_squared_error: 2.0924 - val_loss: 6.2256 - val_y1_output_loss: 2.3094 - val_y2_output_loss: 3.7865 - val_y1_output_root_mean_squared_error: 1.5151 - val_y2_output_root_mean_squared_error: 1.9825
# Epoch 50/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.8958 - y1_output_loss: 2.0518 - y2_output_loss: 4.9677 - y1_output_root_mean_squared_error: 1.4192 - y2_output_root_mean_squared_error: 2.2095 - val_loss: 18.8114 - val_y1_output_loss: 3.0452 - val_y2_output_loss: 15.3859 - val_y1_output_root_mean_squared_error: 1.7457 - val_y2_output_root_mean_squared_error: 3.9704
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.9389 - y1_output_loss: 2.2089 - y2_output_loss: 4.7040 - y1_output_root_mean_squared_error: 1.4879 - y2_output_root_mean_squared_error: 2.1737 - val_loss: 10.9908 - val_y1_output_loss: 4.4426 - val_y2_output_loss: 6.1845 - val_y1_output_root_mean_squared_error: 2.1454 - val_y2_output_root_mean_squared_error: 2.5275
# Epoch 52/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.0844 - y1_output_loss: 1.9888 - y2_output_loss: 4.0672 - y1_output_root_mean_squared_error: 1.4079 - y2_output_root_mean_squared_error: 2.0254 - val_loss: 5.6191 - val_y1_output_loss: 2.0570 - val_y2_output_loss: 3.4288 - val_y1_output_root_mean_squared_error: 1.4352 - val_y2_output_root_mean_squared_error: 1.8866
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0097 - y1_output_loss: 2.0864 - y2_output_loss: 4.8796 - y1_output_root_mean_squared_error: 1.4503 - y2_output_root_mean_squared_error: 2.2151 - val_loss: 5.5127 - val_y1_output_loss: 1.9266 - val_y2_output_loss: 3.4469 - val_y1_output_root_mean_squared_error: 1.3928 - val_y2_output_root_mean_squared_error: 1.8902
# Epoch 54/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.9919 - y1_output_loss: 1.9902 - y2_output_loss: 4.9360 - y1_output_root_mean_squared_error: 1.4174 - y2_output_root_mean_squared_error: 2.2323 - val_loss: 5.7360 - val_y1_output_loss: 1.9967 - val_y2_output_loss: 3.5708 - val_y1_output_root_mean_squared_error: 1.4311 - val_y2_output_root_mean_squared_error: 1.9204
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.4654 - y1_output_loss: 2.0293 - y2_output_loss: 4.4852 - y1_output_root_mean_squared_error: 1.4132 - y2_output_root_mean_squared_error: 2.1138 - val_loss: 9.8555 - val_y1_output_loss: 3.2330 - val_y2_output_loss: 6.4680 - val_y1_output_root_mean_squared_error: 1.7864 - val_y2_output_root_mean_squared_error: 2.5815
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.9805 - y1_output_loss: 1.8319 - y2_output_loss: 4.1256 - y1_output_root_mean_squared_error: 1.3568 - y2_output_root_mean_squared_error: 2.0346 - val_loss: 6.1914 - val_y1_output_loss: 1.9441 - val_y2_output_loss: 4.1467 - val_y1_output_root_mean_squared_error: 1.3864 - val_y2_output_root_mean_squared_error: 2.0663
# Epoch 57/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.4918 - y1_output_loss: 2.3860 - y2_output_loss: 6.0290 - y1_output_root_mean_squared_error: 1.5514 - y2_output_root_mean_squared_error: 2.4668 - val_loss: 5.2558 - val_y1_output_loss: 1.7088 - val_y2_output_loss: 3.3972 - val_y1_output_root_mean_squared_error: 1.3140 - val_y2_output_root_mean_squared_error: 1.8786
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.3693 - y1_output_loss: 1.5924 - y2_output_loss: 3.7289 - y1_output_root_mean_squared_error: 1.2672 - y2_output_root_mean_squared_error: 1.9400 - val_loss: 4.9990 - val_y1_output_loss: 1.8600 - val_y2_output_loss: 2.9921 - val_y1_output_root_mean_squared_error: 1.3782 - val_y2_output_root_mean_squared_error: 1.7606
# Epoch 59/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.2167 - y1_output_loss: 1.5587 - y2_output_loss: 3.6334 - y1_output_root_mean_squared_error: 1.2526 - y2_output_root_mean_squared_error: 1.9099 - val_loss: 10.5094 - val_y1_output_loss: 3.0771 - val_y2_output_loss: 7.1800 - val_y1_output_root_mean_squared_error: 1.7804 - val_y2_output_root_mean_squared_error: 2.7091
# Epoch 60/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.5399 - y1_output_loss: 1.7697 - y2_output_loss: 4.7176 - y1_output_root_mean_squared_error: 1.3355 - y2_output_root_mean_squared_error: 2.1809 - val_loss: 5.0183 - val_y1_output_loss: 1.9539 - val_y2_output_loss: 2.9202 - val_y1_output_root_mean_squared_error: 1.4089 - val_y2_output_root_mean_squared_error: 1.7416
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.1248 - y1_output_loss: 1.3943 - y2_output_loss: 3.6853 - y1_output_root_mean_squared_error: 1.1859 - y2_output_root_mean_squared_error: 1.9283 - val_loss: 5.1750 - val_y1_output_loss: 1.7152 - val_y2_output_loss: 3.3250 - val_y1_output_root_mean_squared_error: 1.3198 - val_y2_output_root_mean_squared_error: 1.8529
# Epoch 62/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.4957 - y1_output_loss: 1.5682 - y2_output_loss: 3.9172 - y1_output_root_mean_squared_error: 1.2521 - y2_output_root_mean_squared_error: 1.9819 - val_loss: 4.3818 - val_y1_output_loss: 1.4071 - val_y2_output_loss: 2.8426 - val_y1_output_root_mean_squared_error: 1.2004 - val_y2_output_root_mean_squared_error: 1.7148
# Epoch 63/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.9192 - y1_output_loss: 2.1762 - y2_output_loss: 5.7517 - y1_output_root_mean_squared_error: 1.4738 - y2_output_root_mean_squared_error: 2.3973 - val_loss: 7.2378 - val_y1_output_loss: 2.5180 - val_y2_output_loss: 4.6128 - val_y1_output_root_mean_squared_error: 1.6129 - val_y2_output_root_mean_squared_error: 2.1532
# Epoch 64/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.0303 - y1_output_loss: 2.4583 - y2_output_loss: 6.5185 - y1_output_root_mean_squared_error: 1.5697 - y2_output_root_mean_squared_error: 2.5625 - val_loss: 5.0256 - val_y1_output_loss: 1.5209 - val_y2_output_loss: 3.3728 - val_y1_output_root_mean_squared_error: 1.2419 - val_y2_output_root_mean_squared_error: 1.8663
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.0367 - y1_output_loss: 1.6327 - y2_output_loss: 3.3782 - y1_output_root_mean_squared_error: 1.2758 - y2_output_root_mean_squared_error: 1.8464 - val_loss: 6.7448 - val_y1_output_loss: 2.6053 - val_y2_output_loss: 3.9455 - val_y1_output_root_mean_squared_error: 1.6410 - val_y2_output_root_mean_squared_error: 2.0129
# Epoch 66/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0926 - y1_output_loss: 1.6900 - y2_output_loss: 4.3893 - y1_output_root_mean_squared_error: 1.2947 - y2_output_root_mean_squared_error: 2.1015 - val_loss: 4.5726 - val_y1_output_loss: 1.1693 - val_y2_output_loss: 3.3147 - val_y1_output_root_mean_squared_error: 1.0731 - val_y2_output_root_mean_squared_error: 1.8496
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.1778 - y1_output_loss: 2.2459 - y2_output_loss: 5.9033 - y1_output_root_mean_squared_error: 1.5031 - y2_output_root_mean_squared_error: 2.4328 - val_loss: 4.1624 - val_y1_output_loss: 1.3654 - val_y2_output_loss: 2.7403 - val_y1_output_root_mean_squared_error: 1.1661 - val_y2_output_root_mean_squared_error: 1.6741
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5875 - y1_output_loss: 1.1777 - y2_output_loss: 3.4126 - y1_output_root_mean_squared_error: 1.0815 - y2_output_root_mean_squared_error: 1.8487 - val_loss: 5.2618 - val_y1_output_loss: 2.0744 - val_y2_output_loss: 3.0640 - val_y1_output_root_mean_squared_error: 1.4512 - val_y2_output_root_mean_squared_error: 1.7764
# Epoch 69/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0128 - y1_output_loss: 1.0781 - y2_output_loss: 2.9011 - y1_output_root_mean_squared_error: 1.0432 - y2_output_root_mean_squared_error: 1.7102 - val_loss: 3.4049 - val_y1_output_loss: 1.0806 - val_y2_output_loss: 2.2307 - val_y1_output_root_mean_squared_error: 1.0458 - val_y2_output_root_mean_squared_error: 1.5203
# Epoch 70/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.4945 - y1_output_loss: 1.1821 - y2_output_loss: 3.4480 - y1_output_root_mean_squared_error: 1.0699 - y2_output_root_mean_squared_error: 1.8303 - val_loss: 6.7549 - val_y1_output_loss: 2.4742 - val_y2_output_loss: 4.0978 - val_y1_output_root_mean_squared_error: 1.5936 - val_y2_output_root_mean_squared_error: 2.0532
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.7959 - y1_output_loss: 2.1970 - y2_output_loss: 5.7230 - y1_output_root_mean_squared_error: 1.4647 - y2_output_root_mean_squared_error: 2.3771 - val_loss: 25.1431 - val_y1_output_loss: 5.3558 - val_y2_output_loss: 19.3072 - val_y1_output_root_mean_squared_error: 2.3203 - val_y2_output_root_mean_squared_error: 4.4452
# Epoch 72/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7818 - y1_output_loss: 1.5196 - y2_output_loss: 4.4350 - y1_output_root_mean_squared_error: 1.2200 - y2_output_root_mean_squared_error: 2.0720 - val_loss: 25.3813 - val_y1_output_loss: 4.3920 - val_y2_output_loss: 20.2917 - val_y1_output_root_mean_squared_error: 2.1157 - val_y2_output_root_mean_squared_error: 4.5722
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.9840 - y1_output_loss: 1.9536 - y2_output_loss: 4.9722 - y1_output_root_mean_squared_error: 1.4039 - y2_output_root_mean_squared_error: 2.2390 - val_loss: 3.2746 - val_y1_output_loss: 0.8951 - val_y2_output_loss: 2.2943 - val_y1_output_root_mean_squared_error: 0.9454 - val_y2_output_root_mean_squared_error: 1.5430
# Epoch 74/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2452 - y1_output_loss: 1.0624 - y2_output_loss: 3.1603 - y1_output_root_mean_squared_error: 1.0291 - y2_output_root_mean_squared_error: 1.7850 - val_loss: 3.5062 - val_y1_output_loss: 1.1115 - val_y2_output_loss: 2.3150 - val_y1_output_root_mean_squared_error: 1.0532 - val_y2_output_root_mean_squared_error: 1.5482
# Epoch 75/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.8928 - y1_output_loss: 2.9013 - y2_output_loss: 5.9262 - y1_output_root_mean_squared_error: 1.7073 - y2_output_root_mean_squared_error: 2.4450 - val_loss: 3.4143 - val_y1_output_loss: 0.9347 - val_y2_output_loss: 2.3925 - val_y1_output_root_mean_squared_error: 0.9734 - val_y2_output_root_mean_squared_error: 1.5706
# Epoch 76/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4946 - y1_output_loss: 0.8355 - y2_output_loss: 2.7003 - y1_output_root_mean_squared_error: 0.9127 - y2_output_root_mean_squared_error: 1.6314 - val_loss: 9.7157 - val_y1_output_loss: 2.3036 - val_y2_output_loss: 7.2111 - val_y1_output_root_mean_squared_error: 1.5463 - val_y2_output_root_mean_squared_error: 2.7064
# Epoch 77/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.7947 - y1_output_loss: 1.0243 - y2_output_loss: 3.7762 - y1_output_root_mean_squared_error: 1.0156 - y2_output_root_mean_squared_error: 1.9399 - val_loss: 3.7211 - val_y1_output_loss: 1.1419 - val_y2_output_loss: 2.4647 - val_y1_output_root_mean_squared_error: 1.0865 - val_y2_output_root_mean_squared_error: 1.5939
# Epoch 78/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0957 - y1_output_loss: 0.9786 - y2_output_loss: 3.0901 - y1_output_root_mean_squared_error: 0.9934 - y2_output_root_mean_squared_error: 1.7632 - val_loss: 4.0702 - val_y1_output_loss: 1.1819 - val_y2_output_loss: 2.8042 - val_y1_output_root_mean_squared_error: 1.0807 - val_y2_output_root_mean_squared_error: 1.7036
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.0465 - y1_output_loss: 1.8962 - y2_output_loss: 5.1181 - y1_output_root_mean_squared_error: 1.3751 - y2_output_root_mean_squared_error: 2.2706 - val_loss: 4.4449 - val_y1_output_loss: 1.4168 - val_y2_output_loss: 2.9425 - val_y1_output_root_mean_squared_error: 1.1804 - val_y2_output_root_mean_squared_error: 1.7469
# Epoch 80/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.8497 - y1_output_loss: 0.9261 - y2_output_loss: 2.8987 - y1_output_root_mean_squared_error: 0.9665 - y2_output_root_mean_squared_error: 1.7075 - val_loss: 3.0015 - val_y1_output_loss: 0.7698 - val_y2_output_loss: 2.1655 - val_y1_output_root_mean_squared_error: 0.8742 - val_y2_output_root_mean_squared_error: 1.4957
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7003 - y1_output_loss: 0.9250 - y2_output_loss: 2.7664 - y1_output_root_mean_squared_error: 0.9656 - y2_output_root_mean_squared_error: 1.6637 - val_loss: 3.4700 - val_y1_output_loss: 0.7419 - val_y2_output_loss: 2.6713 - val_y1_output_root_mean_squared_error: 0.8705 - val_y2_output_root_mean_squared_error: 1.6469
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2405 - y1_output_loss: 0.6837 - y2_output_loss: 2.5675 - y1_output_root_mean_squared_error: 0.8279 - y2_output_root_mean_squared_error: 1.5985 - val_loss: 3.3942 - val_y1_output_loss: 0.8731 - val_y2_output_loss: 2.4349 - val_y1_output_root_mean_squared_error: 0.9453 - val_y2_output_root_mean_squared_error: 1.5813
# Epoch 83/500
# 614/614 [==============================] - 0s 183us/sample - loss: 3.6567 - y1_output_loss: 0.9244 - y2_output_loss: 2.7406 - y1_output_root_mean_squared_error: 0.9598 - y2_output_root_mean_squared_error: 1.6539 - val_loss: 4.2893 - val_y1_output_loss: 1.2803 - val_y2_output_loss: 2.9563 - val_y1_output_root_mean_squared_error: 1.1288 - val_y2_output_root_mean_squared_error: 1.7364
# Epoch 84/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8485 - y1_output_loss: 1.0143 - y2_output_loss: 2.8301 - y1_output_root_mean_squared_error: 1.0051 - y2_output_root_mean_squared_error: 1.6847 - val_loss: 2.8866 - val_y1_output_loss: 0.7080 - val_y2_output_loss: 2.1180 - val_y1_output_root_mean_squared_error: 0.8484 - val_y2_output_root_mean_squared_error: 1.4720
# Epoch 85/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6643 - y1_output_loss: 0.8492 - y2_output_loss: 2.7951 - y1_output_root_mean_squared_error: 0.9186 - y2_output_root_mean_squared_error: 1.6794 - val_loss: 4.2440 - val_y1_output_loss: 1.1223 - val_y2_output_loss: 3.0272 - val_y1_output_root_mean_squared_error: 1.0670 - val_y2_output_root_mean_squared_error: 1.7623
# Epoch 86/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.3059 - y1_output_loss: 0.9655 - y2_output_loss: 3.3091 - y1_output_root_mean_squared_error: 0.9868 - y2_output_root_mean_squared_error: 1.8254 - val_loss: 3.9404 - val_y1_output_loss: 1.1300 - val_y2_output_loss: 2.7115 - val_y1_output_root_mean_squared_error: 1.0767 - val_y2_output_root_mean_squared_error: 1.6677
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5582 - y1_output_loss: 0.8734 - y2_output_loss: 2.7022 - y1_output_root_mean_squared_error: 0.9351 - y2_output_root_mean_squared_error: 1.6382 - val_loss: 4.1971 - val_y1_output_loss: 1.7091 - val_y2_output_loss: 2.3641 - val_y1_output_root_mean_squared_error: 1.3199 - val_y2_output_root_mean_squared_error: 1.5668
# Epoch 88/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.5465 - y1_output_loss: 0.8486 - y2_output_loss: 2.6904 - y1_output_root_mean_squared_error: 0.9245 - y2_output_root_mean_squared_error: 1.6407 - val_loss: 3.3054 - val_y1_output_loss: 0.7017 - val_y2_output_loss: 2.5413 - val_y1_output_root_mean_squared_error: 0.8369 - val_y2_output_root_mean_squared_error: 1.6140
# Epoch 89/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2557 - y1_output_loss: 0.9958 - y2_output_loss: 3.4121 - y1_output_root_mean_squared_error: 0.9543 - y2_output_root_mean_squared_error: 1.8289 - val_loss: 16.9135 - val_y1_output_loss: 4.8945 - val_y2_output_loss: 11.7034 - val_y1_output_root_mean_squared_error: 2.2168 - val_y2_output_root_mean_squared_error: 3.4640
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6091 - y1_output_loss: 0.8948 - y2_output_loss: 2.7309 - y1_output_root_mean_squared_error: 0.9473 - y2_output_root_mean_squared_error: 1.6467 - val_loss: 4.8555 - val_y1_output_loss: 0.6268 - val_y2_output_loss: 4.0984 - val_y1_output_root_mean_squared_error: 0.7880 - val_y2_output_root_mean_squared_error: 2.0578
# Epoch 91/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0930 - y1_output_loss: 1.0714 - y2_output_loss: 2.9960 - y1_output_root_mean_squared_error: 1.0351 - y2_output_root_mean_squared_error: 1.7382 - val_loss: 2.4864 - val_y1_output_loss: 0.6107 - val_y2_output_loss: 1.8145 - val_y1_output_root_mean_squared_error: 0.7785 - val_y2_output_root_mean_squared_error: 1.3712
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6333 - y1_output_loss: 0.5824 - y2_output_loss: 2.0398 - y1_output_root_mean_squared_error: 0.7655 - y2_output_root_mean_squared_error: 1.4309 - val_loss: 3.4174 - val_y1_output_loss: 0.5548 - val_y2_output_loss: 2.7604 - val_y1_output_root_mean_squared_error: 0.7487 - val_y2_output_root_mean_squared_error: 1.6902
# Epoch 93/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2097 - y1_output_loss: 0.7913 - y2_output_loss: 2.4266 - y1_output_root_mean_squared_error: 0.8913 - y2_output_root_mean_squared_error: 1.5541 - val_loss: 9.6849 - val_y1_output_loss: 1.1135 - val_y2_output_loss: 8.3630 - val_y1_output_root_mean_squared_error: 1.0434 - val_y2_output_root_mean_squared_error: 2.9319
# Epoch 94/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.9983 - y1_output_loss: 1.6886 - y2_output_loss: 4.2578 - y1_output_root_mean_squared_error: 1.3043 - y2_output_root_mean_squared_error: 2.0729 - val_loss: 2.4280 - val_y1_output_loss: 0.6910 - val_y2_output_loss: 1.6920 - val_y1_output_root_mean_squared_error: 0.8325 - val_y2_output_root_mean_squared_error: 1.3172
# Epoch 95/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0947 - y1_output_loss: 0.6929 - y2_output_loss: 2.3792 - y1_output_root_mean_squared_error: 0.8357 - y2_output_root_mean_squared_error: 1.5480 - val_loss: 2.4391 - val_y1_output_loss: 0.6186 - val_y2_output_loss: 1.7524 - val_y1_output_root_mean_squared_error: 0.7925 - val_y2_output_root_mean_squared_error: 1.3457
# Epoch 96/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2398 - y1_output_loss: 0.6700 - y2_output_loss: 2.5566 - y1_output_root_mean_squared_error: 0.8168 - y2_output_root_mean_squared_error: 1.6040 - val_loss: 2.2498 - val_y1_output_loss: 0.5939 - val_y2_output_loss: 1.6224 - val_y1_output_root_mean_squared_error: 0.7713 - val_y2_output_root_mean_squared_error: 1.2864
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1558 - y1_output_loss: 0.6295 - y2_output_loss: 2.5661 - y1_output_root_mean_squared_error: 0.7946 - y2_output_root_mean_squared_error: 1.5888 - val_loss: 2.4663 - val_y1_output_loss: 0.9401 - val_y2_output_loss: 1.4525 - val_y1_output_root_mean_squared_error: 0.9841 - val_y2_output_root_mean_squared_error: 1.2239
# Epoch 98/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0184 - y1_output_loss: 0.6301 - y2_output_loss: 2.3730 - y1_output_root_mean_squared_error: 0.7901 - y2_output_root_mean_squared_error: 1.5473 - val_loss: 2.1678 - val_y1_output_loss: 0.7391 - val_y2_output_loss: 1.4343 - val_y1_output_root_mean_squared_error: 0.8545 - val_y2_output_root_mean_squared_error: 1.1991
# Epoch 99/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2690 - y1_output_loss: 0.8855 - y2_output_loss: 3.3867 - y1_output_root_mean_squared_error: 0.9433 - y2_output_root_mean_squared_error: 1.8382 - val_loss: 3.8645 - val_y1_output_loss: 0.6392 - val_y2_output_loss: 3.1673 - val_y1_output_root_mean_squared_error: 0.8047 - val_y2_output_root_mean_squared_error: 1.7936
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.9714 - y1_output_loss: 0.9118 - y2_output_loss: 3.0358 - y1_output_root_mean_squared_error: 0.9556 - y2_output_root_mean_squared_error: 1.7488 - val_loss: 2.9107 - val_y1_output_loss: 0.7022 - val_y2_output_loss: 2.1471 - val_y1_output_root_mean_squared_error: 0.8425 - val_y2_output_root_mean_squared_error: 1.4835
# Epoch 101/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5067 - y1_output_loss: 0.8374 - y2_output_loss: 2.6666 - y1_output_root_mean_squared_error: 0.9137 - y2_output_root_mean_squared_error: 1.6346 - val_loss: 2.0968 - val_y1_output_loss: 0.5174 - val_y2_output_loss: 1.5486 - val_y1_output_root_mean_squared_error: 0.7164 - val_y2_output_root_mean_squared_error: 1.2584
# Epoch 102/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6048 - y1_output_loss: 0.7329 - y2_output_loss: 2.8735 - y1_output_root_mean_squared_error: 0.8518 - y2_output_root_mean_squared_error: 1.6968 - val_loss: 3.6674 - val_y1_output_loss: 0.8701 - val_y2_output_loss: 2.7373 - val_y1_output_root_mean_squared_error: 0.9230 - val_y2_output_root_mean_squared_error: 1.6780
# Epoch 103/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.5541 - y1_output_loss: 0.5732 - y2_output_loss: 2.0346 - y1_output_root_mean_squared_error: 0.7565 - y2_output_root_mean_squared_error: 1.4077 - val_loss: 4.9000 - val_y1_output_loss: 0.9218 - val_y2_output_loss: 3.8695 - val_y1_output_root_mean_squared_error: 0.9716 - val_y2_output_root_mean_squared_error: 1.9890
# Epoch 104/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2545 - y1_output_loss: 1.1094 - y2_output_loss: 3.1250 - y1_output_root_mean_squared_error: 1.0557 - y2_output_root_mean_squared_error: 1.7720 - val_loss: 2.0238 - val_y1_output_loss: 0.4231 - val_y2_output_loss: 1.5498 - val_y1_output_root_mean_squared_error: 0.6486 - val_y2_output_root_mean_squared_error: 1.2662
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.1569 - y1_output_loss: 2.9154 - y2_output_loss: 6.1931 - y1_output_root_mean_squared_error: 1.7137 - y2_output_root_mean_squared_error: 2.4940 - val_loss: 4.7073 - val_y1_output_loss: 1.9646 - val_y2_output_loss: 2.6168 - val_y1_output_root_mean_squared_error: 1.4178 - val_y2_output_root_mean_squared_error: 1.6423
# Epoch 106/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9623 - y1_output_loss: 0.7088 - y2_output_loss: 2.2536 - y1_output_root_mean_squared_error: 0.8445 - y2_output_root_mean_squared_error: 1.4997 - val_loss: 2.6362 - val_y1_output_loss: 0.6522 - val_y2_output_loss: 1.9324 - val_y1_output_root_mean_squared_error: 0.8183 - val_y2_output_root_mean_squared_error: 1.4024
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4088 - y1_output_loss: 0.5010 - y2_output_loss: 1.8898 - y1_output_root_mean_squared_error: 0.7082 - y2_output_root_mean_squared_error: 1.3810 - val_loss: 2.3059 - val_y1_output_loss: 0.8103 - val_y2_output_loss: 1.4534 - val_y1_output_root_mean_squared_error: 0.9025 - val_y2_output_root_mean_squared_error: 1.2212
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.7424 - y1_output_loss: 0.7652 - y2_output_loss: 2.9516 - y1_output_root_mean_squared_error: 0.8745 - y2_output_root_mean_squared_error: 1.7256 - val_loss: 2.1530 - val_y1_output_loss: 0.5301 - val_y2_output_loss: 1.5842 - val_y1_output_root_mean_squared_error: 0.7157 - val_y2_output_root_mean_squared_error: 1.2809
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5408 - y1_output_loss: 0.5135 - y2_output_loss: 2.0286 - y1_output_root_mean_squared_error: 0.7116 - y2_output_root_mean_squared_error: 1.4263 - val_loss: 2.1614 - val_y1_output_loss: 0.5895 - val_y2_output_loss: 1.5123 - val_y1_output_root_mean_squared_error: 0.7811 - val_y2_output_root_mean_squared_error: 1.2455
# Epoch 110/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.8580 - y1_output_loss: 0.6301 - y2_output_loss: 2.2291 - y1_output_root_mean_squared_error: 0.7967 - y2_output_root_mean_squared_error: 1.4911 - val_loss: 2.4333 - val_y1_output_loss: 0.5830 - val_y2_output_loss: 1.7987 - val_y1_output_root_mean_squared_error: 0.7740 - val_y2_output_root_mean_squared_error: 1.3544
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6132 - y1_output_loss: 0.6256 - y2_output_loss: 1.9792 - y1_output_root_mean_squared_error: 0.7931 - y2_output_root_mean_squared_error: 1.4086 - val_loss: 2.3830 - val_y1_output_loss: 0.5202 - val_y2_output_loss: 1.8017 - val_y1_output_root_mean_squared_error: 0.7230 - val_y2_output_root_mean_squared_error: 1.3639
# Epoch 112/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4075 - y1_output_loss: 0.4912 - y2_output_loss: 1.9111 - y1_output_root_mean_squared_error: 0.7000 - y2_output_root_mean_squared_error: 1.3847 - val_loss: 3.3419 - val_y1_output_loss: 0.5688 - val_y2_output_loss: 2.6991 - val_y1_output_root_mean_squared_error: 0.7508 - val_y2_output_root_mean_squared_error: 1.6668
# Epoch 113/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.5597 - y1_output_loss: 1.2768 - y2_output_loss: 3.3175 - y1_output_root_mean_squared_error: 1.1333 - y2_output_root_mean_squared_error: 1.8098 - val_loss: 3.6803 - val_y1_output_loss: 0.7921 - val_y2_output_loss: 2.8251 - val_y1_output_root_mean_squared_error: 0.9013 - val_y2_output_root_mean_squared_error: 1.6935
# Epoch 114/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2751 - y1_output_loss: 0.9647 - y2_output_loss: 3.2823 - y1_output_root_mean_squared_error: 0.9837 - y2_output_root_mean_squared_error: 1.8186 - val_loss: 1.9615 - val_y1_output_loss: 0.4780 - val_y2_output_loss: 1.4326 - val_y1_output_root_mean_squared_error: 0.6962 - val_y2_output_root_mean_squared_error: 1.2152
# Epoch 115/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4182 - y1_output_loss: 0.5250 - y2_output_loss: 1.9127 - y1_output_root_mean_squared_error: 0.7266 - y2_output_root_mean_squared_error: 1.3749 - val_loss: 5.0705 - val_y1_output_loss: 0.4642 - val_y2_output_loss: 4.4776 - val_y1_output_root_mean_squared_error: 0.6845 - val_y2_output_root_mean_squared_error: 2.1452
# Epoch 116/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8837 - y1_output_loss: 1.0836 - y2_output_loss: 3.5139 - y1_output_root_mean_squared_error: 0.9350 - y2_output_root_mean_squared_error: 1.7348 - val_loss: 164.7994 - val_y1_output_loss: 62.5057 - val_y2_output_loss: 97.5116 - val_y1_output_root_mean_squared_error: 8.0352 - val_y2_output_root_mean_squared_error: 10.0117
# Epoch 117/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.5235 - y1_output_loss: 3.7737 - y2_output_loss: 8.6455 - y1_output_root_mean_squared_error: 1.9503 - y2_output_root_mean_squared_error: 2.9530 - val_loss: 2.7440 - val_y1_output_loss: 0.6129 - val_y2_output_loss: 2.0739 - val_y1_output_root_mean_squared_error: 0.7957 - val_y2_output_root_mean_squared_error: 1.4529
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2480 - y1_output_loss: 0.4716 - y2_output_loss: 1.7730 - y1_output_root_mean_squared_error: 0.6899 - y2_output_root_mean_squared_error: 1.3312 - val_loss: 2.3280 - val_y1_output_loss: 0.3776 - val_y2_output_loss: 1.8836 - val_y1_output_root_mean_squared_error: 0.6173 - val_y2_output_root_mean_squared_error: 1.3953
# Epoch 119/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.3339 - y1_output_loss: 1.6726 - y2_output_loss: 4.6137 - y1_output_root_mean_squared_error: 1.2993 - y2_output_root_mean_squared_error: 2.1554 - val_loss: 3.0011 - val_y1_output_loss: 1.1322 - val_y2_output_loss: 1.7717 - val_y1_output_root_mean_squared_error: 1.0797 - val_y2_output_root_mean_squared_error: 1.3547
# Epoch 120/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7542 - y1_output_loss: 0.5864 - y2_output_loss: 2.1481 - y1_output_root_mean_squared_error: 0.7691 - y2_output_root_mean_squared_error: 1.4706 - val_loss: 2.2007 - val_y1_output_loss: 0.5827 - val_y2_output_loss: 1.6092 - val_y1_output_root_mean_squared_error: 0.7746 - val_y2_output_root_mean_squared_error: 1.2652
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3326 - y1_output_loss: 0.1233 - y2_output_loss: 0.2087 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 0.9168 - val_y1_output_loss: 0.2258 - val_y2_output_loss: 0.6853 - val_y1_output_root_mean_squared_error: 0.4832 - val_y2_output_root_mean_squared_error: 0.8267
# Epoch 462/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5650 - y1_output_loss: 0.1614 - y2_output_loss: 0.4021 - y1_output_root_mean_squared_error: 0.4036 - y2_output_root_mean_squared_error: 0.6341 - val_loss: 0.6351 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 0.4603 - val_y1_output_root_mean_squared_error: 0.4054 - val_y2_output_root_mean_squared_error: 0.6861
# Epoch 463/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4102 - y1_output_loss: 0.1274 - y2_output_loss: 0.2830 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.5318 - val_loss: 0.5647 - val_y1_output_loss: 0.1676 - val_y2_output_loss: 0.3828 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 0.6258
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4321 - y1_output_loss: 0.1246 - y2_output_loss: 0.3045 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5539 - val_loss: 0.6401 - val_y1_output_loss: 0.1715 - val_y2_output_loss: 0.4585 - val_y1_output_root_mean_squared_error: 0.4216 - val_y2_output_root_mean_squared_error: 0.6800
# Epoch 465/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3585 - y1_output_loss: 0.1178 - y2_output_loss: 0.2381 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.4896 - val_loss: 0.5769 - val_y1_output_loss: 0.1433 - val_y2_output_loss: 0.4258 - val_y1_output_root_mean_squared_error: 0.3852 - val_y2_output_root_mean_squared_error: 0.6546
# Epoch 466/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4122 - y1_output_loss: 0.1378 - y2_output_loss: 0.2737 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.5247 - val_loss: 0.5684 - val_y1_output_loss: 0.1552 - val_y2_output_loss: 0.3976 - val_y1_output_root_mean_squared_error: 0.4007 - val_y2_output_root_mean_squared_error: 0.6386
# Epoch 467/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3982 - y1_output_loss: 0.1159 - y2_output_loss: 0.2798 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.5307 - val_loss: 0.6374 - val_y1_output_loss: 0.1783 - val_y2_output_loss: 0.4444 - val_y1_output_root_mean_squared_error: 0.4299 - val_y2_output_root_mean_squared_error: 0.6728
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4796 - y1_output_loss: 0.1449 - y2_output_loss: 0.3342 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.5777 - val_loss: 0.6907 - val_y1_output_loss: 0.1763 - val_y2_output_loss: 0.4926 - val_y1_output_root_mean_squared_error: 0.4275 - val_y2_output_root_mean_squared_error: 0.7127
# Epoch 469/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4222 - y1_output_loss: 0.1333 - y2_output_loss: 0.2888 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5366 - val_loss: 0.7867 - val_y1_output_loss: 0.1493 - val_y2_output_loss: 0.6109 - val_y1_output_root_mean_squared_error: 0.3933 - val_y2_output_root_mean_squared_error: 0.7950
# Epoch 470/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4002 - y1_output_loss: 0.1198 - y2_output_loss: 0.2778 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5290 - val_loss: 0.7015 - val_y1_output_loss: 0.2031 - val_y2_output_loss: 0.4797 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 0.7016
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4879 - y1_output_loss: 0.1387 - y2_output_loss: 0.3512 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5903 - val_loss: 1.0766 - val_y1_output_loss: 0.2333 - val_y2_output_loss: 0.8103 - val_y1_output_root_mean_squared_error: 0.4906 - val_y2_output_root_mean_squared_error: 0.9143
# Epoch 472/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3855 - y1_output_loss: 0.1245 - y2_output_loss: 0.2624 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 0.7981 - val_y1_output_loss: 0.1842 - val_y2_output_loss: 0.5917 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.7797
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6703 - y1_output_loss: 0.1707 - y2_output_loss: 0.4949 - y1_output_root_mean_squared_error: 0.4148 - y2_output_root_mean_squared_error: 0.7059 - val_loss: 0.8178 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.5958 - val_y1_output_root_mean_squared_error: 0.4639 - val_y2_output_root_mean_squared_error: 0.7763
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3714 - y1_output_loss: 0.1247 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.4969 - val_loss: 0.5961 - val_y1_output_loss: 0.1608 - val_y2_output_loss: 0.4247 - val_y1_output_root_mean_squared_error: 0.4083 - val_y2_output_root_mean_squared_error: 0.6553
# Epoch 475/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4068 - y1_output_loss: 0.1224 - y2_output_loss: 0.3137 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5336 - val_loss: 3.5049 - val_y1_output_loss: 0.4050 - val_y2_output_loss: 3.1652 - val_y1_output_root_mean_squared_error: 0.6398 - val_y2_output_root_mean_squared_error: 1.7594
# Epoch 476/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6233 - y1_output_loss: 0.1574 - y2_output_loss: 0.4657 - y1_output_root_mean_squared_error: 0.3986 - y2_output_root_mean_squared_error: 0.6815 - val_loss: 0.7668 - val_y1_output_loss: 0.1478 - val_y2_output_loss: 0.5950 - val_y1_output_root_mean_squared_error: 0.3918 - val_y2_output_root_mean_squared_error: 0.7831
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3777 - y1_output_loss: 0.1206 - y2_output_loss: 0.2611 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5084 - val_loss: 0.7977 - val_y1_output_loss: 0.2627 - val_y2_output_loss: 0.5189 - val_y1_output_root_mean_squared_error: 0.5184 - val_y2_output_root_mean_squared_error: 0.7274
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3540 - y1_output_loss: 0.1147 - y2_output_loss: 0.2391 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4881 - val_loss: 0.6055 - val_y1_output_loss: 0.1680 - val_y2_output_loss: 0.4178 - val_y1_output_root_mean_squared_error: 0.4164 - val_y2_output_root_mean_squared_error: 0.6573
# Epoch 479/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5764 - y1_output_loss: 0.1708 - y2_output_loss: 0.4046 - y1_output_root_mean_squared_error: 0.4139 - y2_output_root_mean_squared_error: 0.6365 - val_loss: 0.8836 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.6563 - val_y1_output_root_mean_squared_error: 0.4586 - val_y2_output_root_mean_squared_error: 0.8205
# Epoch 480/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4651 - y1_output_loss: 0.1382 - y2_output_loss: 0.3241 - y1_output_root_mean_squared_error: 0.3726 - y2_output_root_mean_squared_error: 0.5712 - val_loss: 0.5887 - val_y1_output_loss: 0.1575 - val_y2_output_loss: 0.4141 - val_y1_output_root_mean_squared_error: 0.4042 - val_y2_output_root_mean_squared_error: 0.6522
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4412 - y1_output_loss: 0.1344 - y2_output_loss: 0.3047 - y1_output_root_mean_squared_error: 0.3678 - y2_output_root_mean_squared_error: 0.5531 - val_loss: 0.5750 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.4067 - val_y1_output_root_mean_squared_error: 0.4102 - val_y2_output_root_mean_squared_error: 0.6377
# Epoch 482/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3846 - y1_output_loss: 0.1278 - y2_output_loss: 0.2539 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5059 - val_loss: 0.5802 - val_y1_output_loss: 0.1482 - val_y2_output_loss: 0.4177 - val_y1_output_root_mean_squared_error: 0.3920 - val_y2_output_root_mean_squared_error: 0.6531
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4814 - y1_output_loss: 0.1371 - y2_output_loss: 0.3427 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5860 - val_loss: 0.5554 - val_y1_output_loss: 0.1696 - val_y2_output_loss: 0.3739 - val_y1_output_root_mean_squared_error: 0.4196 - val_y2_output_root_mean_squared_error: 0.6159
# Epoch 484/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3984 - y1_output_loss: 0.1261 - y2_output_loss: 0.2706 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5216 - val_loss: 0.5782 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.3769 - val_y1_output_root_mean_squared_error: 0.4394 - val_y2_output_root_mean_squared_error: 0.6206
# Epoch 485/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4723 - y1_output_loss: 0.1327 - y2_output_loss: 0.3437 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.5831 - val_loss: 0.7051 - val_y1_output_loss: 0.1508 - val_y2_output_loss: 0.5567 - val_y1_output_root_mean_squared_error: 0.3953 - val_y2_output_root_mean_squared_error: 0.7408
# Epoch 486/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3843 - y1_output_loss: 0.1160 - y2_output_loss: 0.2699 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.5186 - val_loss: 0.7926 - val_y1_output_loss: 0.2965 - val_y2_output_loss: 0.4766 - val_y1_output_root_mean_squared_error: 0.5549 - val_y2_output_root_mean_squared_error: 0.6962
# Epoch 487/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4588 - y1_output_loss: 0.1514 - y2_output_loss: 0.3040 - y1_output_root_mean_squared_error: 0.3903 - y2_output_root_mean_squared_error: 0.5536 - val_loss: 0.6051 - val_y1_output_loss: 0.1877 - val_y2_output_loss: 0.4109 - val_y1_output_root_mean_squared_error: 0.4413 - val_y2_output_root_mean_squared_error: 0.6405
# Epoch 488/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4351 - y1_output_loss: 0.1378 - y2_output_loss: 0.2973 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5451 - val_loss: 0.6868 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 0.5059 - val_y1_output_root_mean_squared_error: 0.4097 - val_y2_output_root_mean_squared_error: 0.7204
# Epoch 489/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4958 - y1_output_loss: 0.1593 - y2_output_loss: 0.3390 - y1_output_root_mean_squared_error: 0.3992 - y2_output_root_mean_squared_error: 0.5800 - val_loss: 1.8595 - val_y1_output_loss: 0.3310 - val_y2_output_loss: 1.5037 - val_y1_output_root_mean_squared_error: 0.5856 - val_y2_output_root_mean_squared_error: 1.2315
# Epoch 490/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5213 - y1_output_loss: 0.1468 - y2_output_loss: 0.3720 - y1_output_root_mean_squared_error: 0.3829 - y2_output_root_mean_squared_error: 0.6121 - val_loss: 0.6322 - val_y1_output_loss: 0.1624 - val_y2_output_loss: 0.4678 - val_y1_output_root_mean_squared_error: 0.4101 - val_y2_output_root_mean_squared_error: 0.6812
# Epoch 491/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4401 - y1_output_loss: 0.1358 - y2_output_loss: 0.3033 - y1_output_root_mean_squared_error: 0.3680 - y2_output_root_mean_squared_error: 0.5520 - val_loss: 0.6856 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.4621 - val_y1_output_root_mean_squared_error: 0.4637 - val_y2_output_root_mean_squared_error: 0.6860
# Epoch 492/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5237 - y1_output_loss: 0.1357 - y2_output_loss: 0.3852 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.6227 - val_loss: 0.6072 - val_y1_output_loss: 0.1531 - val_y2_output_loss: 0.4353 - val_y1_output_root_mean_squared_error: 0.3981 - val_y2_output_root_mean_squared_error: 0.6698
# Epoch 493/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5024 - y1_output_loss: 0.1407 - y2_output_loss: 0.3608 - y1_output_root_mean_squared_error: 0.3757 - y2_output_root_mean_squared_error: 0.6010 - val_loss: 0.9070 - val_y1_output_loss: 0.1588 - val_y2_output_loss: 0.7182 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 0.8617
# Epoch 494/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3665 - y1_output_loss: 0.1216 - y2_output_loss: 0.2417 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.4938 - val_loss: 0.6887 - val_y1_output_loss: 0.1558 - val_y2_output_loss: 0.5109 - val_y1_output_root_mean_squared_error: 0.4017 - val_y2_output_root_mean_squared_error: 0.7262
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3900 - y1_output_loss: 0.1273 - y2_output_loss: 0.2688 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5143 - val_loss: 1.0237 - val_y1_output_loss: 0.2949 - val_y2_output_loss: 0.6949 - val_y1_output_root_mean_squared_error: 0.5530 - val_y2_output_root_mean_squared_error: 0.8473
# Epoch 496/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4576 - y1_output_loss: 0.1463 - y2_output_loss: 0.3077 - y1_output_root_mean_squared_error: 0.3841 - y2_output_root_mean_squared_error: 0.5569 - val_loss: 0.5773 - val_y1_output_loss: 0.1751 - val_y2_output_loss: 0.3907 - val_y1_output_root_mean_squared_error: 0.4257 - val_y2_output_root_mean_squared_error: 0.6293
# Epoch 497/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4004 - y1_output_loss: 0.1306 - y2_output_loss: 0.2688 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.5203 - val_loss: 0.6016 - val_y1_output_loss: 0.2056 - val_y2_output_loss: 0.3813 - val_y1_output_root_mean_squared_error: 0.4611 - val_y2_output_root_mean_squared_error: 0.6237
# Epoch 498/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4166 - y1_output_loss: 0.1252 - y2_output_loss: 0.2931 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5390 - val_loss: 0.6909 - val_y1_output_loss: 0.1870 - val_y2_output_loss: 0.4920 - val_y1_output_root_mean_squared_error: 0.4402 - val_y2_output_root_mean_squared_error: 0.7050
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4830 - y1_output_loss: 0.1417 - y2_output_loss: 0.3376 - y1_output_root_mean_squared_error: 0.3779 - y2_output_root_mean_squared_error: 0.5833 - val_loss: 0.5868 - val_y1_output_loss: 0.1518 - val_y2_output_loss: 0.4168 - val_y1_output_root_mean_squared_error: 0.3964 - val_y2_output_root_mean_squared_error: 0.6555
# Epoch 500/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5367 - y1_output_loss: 0.1418 - y2_output_loss: 0.3915 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.6276 - val_loss: 0.7324 - val_y1_output_loss: 0.1705 - val_y2_output_loss: 0.5365 - val_y1_output_root_mean_squared_error: 0.4197 - val_y2_output_root_mean_squared_error: 0.7458

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.7324 - y1_output_loss: 0.1716 - y2_output_loss: 0.5505 - y1_output_root_mean_squared_error: 0.4197 - y2_output_root_mean_squared_error: 0.7458
# Loss = 0.7323856717580325, Y1_loss = 0.17162539064884186, Y1_mse = 0.4197104871273041, Y2_loss = 0.5504751205444336, Y2_mse = 0.7458074688911438

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)

# %%
# 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
